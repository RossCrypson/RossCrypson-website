# %% [markdown]
# <a href="https://colab.research.google.com/github/RossCrypson/RossCrypson-website/blob/main/TF_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This *is* a **heading**

# %% [markdown]
# ```
# # This is formatted as code
# for item in list:
#   print(item)
# ```

# %% [markdown]
# ![HoeYieOnn.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# [Google Search](https://google.com)

# %% [markdown]
# 1.   first
# 2.   second
#
# lai chee choong
# > Eugene is absent today
# he is not feeling well
# > John is in the kitchen
#
# > chan
#
# > lee
#
# > fun
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lai jun yie

# %% [markdown]
# $ ax^2 + bx + c = 0$

# %% [markdown]
# $$x1 = \frac{-b + \sqrt{b^2 - 4ac}}{2a}$$
